# %%
data<-read.csv('DrunkDriving.csv')

# %%
data[1:5,]
# Out:
#   state year fatalityrate beertax legdrinkage jail commserv vmiles unemprate
# 1 1     1982 2.13         1.54    19          no   no       7.23   14.4
# 2 1     1983 2.35         1.79    19          no   no       7.84   13.7
# 3 1     1984 2.34         1.71    19          no   no       8.26   11.1
# 4 1     1985 2.19         1.65    19          no   no       8.73    8.9
# 5 1     1986 2.67         1.61    21          no   no       8.95    9.8
#   incomecap
# 1 10544.15
# 2 10732.80
# 3 11108.79
# 4 11332.63
# 5 11661.51

# %%
attach(data)

# %%
hist(fatalityrate)
# Out:
# Plot with title “Histogram of fatalityrate”

# %%
m1<-lm(fatalityrate~beertax+as.factor(commserv)*as.factor(jail)+incomecap+unemprate)

# %%
summary(m1)
# Out:
# Call:
# lm(formula = fatalityrate ~ beertax + as.factor(commserv) * as.factor(jail) +
#     incomecap + unemprate)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.10240 -0.29849 -0.05897  0.23907  2.04917
#
# Coefficients:
#                                             Estimate Std. Error t value
# (Intercept)                                3.887e+00  2.945e-01  13.201
# beertax                                    1.346e-01  6.167e-02   2.183
# as.factor(commserv)yes                     3.477e-01  1.306e-01   2.664
# as.factor(jail)yes                         3.082e-01  7.936e-02   3.884
# incomecap                                 -1.286e-04  1.556e-05  -8.262
# unemprate                                 -3.151e-02  1.250e-02  -2.522
# as.factor(commserv)yes:as.factor(jail)yes -3.528e-01  1.620e-01  -2.178
#                                           Pr(>|t|)
# (Intercept)                                < 2e-16 ***
# ...

# %%
!install.packages('plm')
# Out:
# also installing the dependencies ‘bdsmatrix’, ‘lmtest’
#
# Warning message in install.packages("plm"):
# “installation of package ‘bdsmatrix’ had non-zero exit status”Warning message in install.packages("plm"):
# “installation of package ‘lmtest’ had non-zero exit status”Warning message in install.packages("plm"):
# “installation of package ‘plm’ had non-zero exit status”Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Error in !install.packages("plm"): invalid argument type
# Traceback:

# %%
library(plm)
# Out:
# Error in library(plm): there is no package called ‘plm’
# Traceback:
#
# 1. library(plm)
# 2. stop(txt, domain = NA)
