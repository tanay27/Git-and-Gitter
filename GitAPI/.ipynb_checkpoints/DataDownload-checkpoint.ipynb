# %%
from gql import gql, Client

# %%
'''''''''''client = Client(schema=schema)
query = gql('''
'{
 # hello
}'
''')

client.execute(query)'''''''''''''
# Out:
#   File "<ipython-input-182-786a7d4caa30>", line 3
#     '{
#       ^
# SyntaxError: EOL while scanning string literal

# %%
import urllib
import requests

# %%
url='https://api.github.com/'

# %%
param={"access_token":"2832f17b43fc92adff4b6c34ca60dab81fb1ac2b"}

# %%
dir(urllib)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'parse']

# %%
dir(urllib.request)
# Out:
# ['AbstractBasicAuthHandler',
#  'AbstractDigestAuthHandler',
#  'AbstractHTTPHandler',
#  'BaseHandler',
#  'CacheFTPHandler',
#  'ContentTooShortError',
#  'DataHandler',
#  'FTPHandler',
#  'FancyURLopener',
#  'FileHandler',
#  'HTTPBasicAuthHandler',
#  'HTTPCookieProcessor',
#  'HTTPDefaultErrorHandler',
#  'HTTPDigestAuthHandler',
#  'HTTPError',
#  'HTTPErrorProcessor',
#  'HTTPHandler',
#  'HTTPPasswordMgr',
#  'HTTPPasswordMgrWithDefaultRealm',
#  'HTTPPasswordMgrWithPriorAuth',
#  'HTTPRedirectHandler',
#  'HTTPSHandler',
#  'MAXFTPCACHE',
#  'OpenerDirector',
#  'ProxyBasicAuthHandler',
#  'ProxyDigestAuthHandler',
#  'ProxyHandler',
#  'Request',
#  'URLError',
#  'URLopener',
#  'UnknownHandler',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__version__',
#  '_cut_port_re',
#  '_ftperrors',
#  '_get_proxies',
#  '_get_proxy_settings',
#  '_have_ssl',
#  '_localhost',
#  '_noheaders',
#  '_opener',
#  '_parse_proxy',
#  '_proxy_bypass_macosx_sysconf',
#  '_randombytes',
#  '_safe_gethostbyname',
#  '_thishost',
#  '_url_tempfiles',
#  'addclosehook',
#  'addinfourl',
#  'base64',
#  'bisect',
#  'build_opener',
#  'collections',
#  'contextlib',
#  'email',
#  'ftpcache',
#  'ftperrors',
#  'ftpwrapper',
#  'getproxies',
#  'getproxies_environment',
#  'getproxies_macosx_sysconf',
#  'hashlib',
#  'http',
#  'install_opener',
#  'io',
#  'localhost',
#  'noheaders',
#  'os',
#  'parse_http_list',
#  'parse_keqv_list',
#  'pathname2url',
#  'posixpath',
#  'proxy_bypass',
#  'proxy_bypass_environment',
#  'proxy_bypass_macosx_sysconf',
#  'quote',
#  're',
#  'request_host',
#  'socket',
#  'splitattr',
#  'splithost',
#  'splitpasswd',
#  'splitport',
#  'splitquery',
#  'splittag',
#  'splittype',
#  'splituser',
#  'splitvalue',
#  'ssl',
#  'string',
#  'sys',
#  'tempfile',
#  'thishost',
#  'time',
#  'to_bytes',
#  'unquote',
#  'unquote_to_bytes',
#  'unwrap',
#  'url2pathname',
#  'urlcleanup',
#  'urljoin',
#  'urlopen',
#  'urlparse',
#  'urlretrieve',
#  'urlsplit',
#  'urlunparse',
#  'warnings']

# %%
res = requests.get('https://api.github.com/')

# %%
res.json()
# Out:
# {'authorizations_url': 'https://api.github.com/authorizations',
#  'code_search_url': 'https://api.github.com/search/code?q={query}{&page,per_page,sort,order}',
#  'commit_search_url': 'https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}',
#  'current_user_authorizations_html_url': 'https://github.com/settings/connections/applications{/client_id}',
#  'current_user_repositories_url': 'https://api.github.com/user/repos{?type,page,per_page,sort}',
#  'current_user_url': 'https://api.github.com/user',
#  'emails_url': 'https://api.github.com/user/emails',
#  'emojis_url': 'https://api.github.com/emojis',
#  'events_url': 'https://api.github.com/events',
#  'feeds_url': 'https://api.github.com/feeds',
#  'followers_url': 'https://api.github.com/user/followers',
#  'following_url': 'https://api.github.com/user/following{/target}',
#  'gists_url': 'https://api.github.com/gists{/gist_id}',
#  'hub_url': 'https://api.github.com/hub',
#  'issue_search_url': 'https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}',
#  'issues_url': 'https://api.github.com/issues',
#  'keys_url': 'https://api.github.com/user/keys',
#  'notifications_url': 'https://api.github.com/notifications',
#  'organization_repositories_url': 'https://api.github.com/orgs/{org}/repos{?type,page,per_page,sort}',
#  'organization_url': 'https://api.github.com/orgs/{org}',
#  'public_gists_url': 'https://api.github.com/gists/public',
#  'rate_limit_url': 'https://api.github.com/rate_limit',
#  'repository_search_url': 'https://api.github.com/search/repositories?q={query}{&page,per_page,sort,order}',
#  'repository_url': 'https://api.github.com/repos/{owner}/{repo}',
#  'starred_gists_url': 'https://api.github.com/gists/starred',
#  'starred_url': 'https://api.github.com/user/starred{/owner}{/repo}',
#  'team_url': 'https://api.github.com/teams',
#  'user_organizations_url': 'https://api.github.com/user/orgs',
#  'user_repositories_url': 'https://api.github.com/users/{user}/repos{?type,page,per_page,sort}',
#  'user_search_url': 'https://api.github.com/search/users?q={query}{&page,per_page,sort,order}',
#  'user_url': 'https://api.github.com/users/{user}'}

# %%
res = requests.get('https://api.github.com/repos/tensorflow/tensorflow').content

# %%
pd.read_json(res)
# Out:
#                                                            archive_url  \
# avatar_url           https://api.github.com/repos/tensorflow/tensor...
# events_url           https://api.github.com/repos/tensorflow/tensor...
# followers_url        https://api.github.com/repos/tensorflow/tensor...
# following_url        https://api.github.com/repos/tensorflow/tensor...
# gists_url            https://api.github.com/repos/tensorflow/tensor...
# gravatar_id          https://api.github.com/repos/tensorflow/tensor...
# html_url             https://api.github.com/repos/tensorflow/tensor...
# id                   https://api.github.com/repos/tensorflow/tensor...
# key                  https://api.github.com/repos/tensorflow/tensor...
# login                https://api.github.com/repos/tensorflow/tensor...
# name                 https://api.github.com/repos/tensorflow/tensor...
# organizations_url    https://api.github.com/repos/tensorflow/tensor...
# received_events_url  https://api.github.com/repos/tensorflow/tensor...
# repos_url            https://api.github.com/repos/tensorflow/tensor...
# site_admin           https://api.github.com/repos/tensorflow/tensor...
# spdx_id              https://api.github.com/repos/tensorflow/tensor...
# starred_url          https://api.github.com/repos/tensorflow/tensor...
# subscriptions_url    https://api.github.com/repos/tensorflow/tensor...
# type                 https://api.github.com/repos/tensorflow/tensor...
# url                  https://api.github.com/repos/tensorflow/tensor...
#
#                      archived  \
# avatar_url              False
# events_url              False
# followers_url           False
# following_url           False
# gists_url               False
# gravatar_id             False
# html_url                False
# id                      False
# key                     False
# login                   False
# name                    False
# organizations_url       False
# received_events_url     False
# repos_url               False
# site_admin              False
# spdx_id                 False
# starred_url             False
# subscriptions_url       False
# type                    False
# url                     False
#
#                                                          assignees_url  \
# avatar_url           https://api.github.com/repos/tensorflow/tensor...
# events_url           https://api.github.com/repos/tensorflow/tensor...
# followers_url        https://api.github.com/repos/tensorflow/tensor...
# following_url        https://api.github.com/repos/tensorflow/tensor...
# gists_url            https://api.github.com/repos/tensorflow/tensor...
# gravatar_id          https://api.github.com/repos/tensorflow/tensor...
# html_url             https://api.github.com/repos/tensorflow/tensor...
# id                   https://api.github.com/repos/tensorflow/tensor...
# key                  https://api.github.com/repos/tensorflow/tensor...
# login                https://api.github.com/repos/tensorflow/tensor...
# name                 https://api.github.com/repos/tensorflow/tensor...
# organizations_url    https://api.github.com/repos/tensorflow/tensor...
# received_events_url  https://api.github.com/repos/tensorflow/tensor...
# repos_url            https://api.github.com/repos/tensorflow/tensor...
# site_admin           https://api.github.com/repos/tensorflow/tensor...
# spdx_id              https://api.github.com/repos/tensorflow/tensor...
# starred_url          https://api.github.com/repos/tensorflow/tensor...
# subscriptions_url    https://api.github.com/repos/tensorflow/tensor...
# type                 https://api.github.com/repos/tensorflow/tensor...
# url                  https://api.github.com/repos/tensorflow/tensor...
#
#                                                              blobs_url  \
# avatar_url           https://api.github.com/repos/tensorflow/tensor...
# events_url           https://api.github.com/repos/tensorflow/tensor...
# followers_url        https://api.github.com/repos/tensorflow/tensor...
# following_url        https://api.github.com/repos/tensorflow/tensor...
# gists_url            https://api.github.com/repos/tensorflow/tensor...
# gravatar_id          https://api.github.com/repos/tensorflow/tensor...
# html_url             https://api.github.com/repos/tensorflow/tensor...
# id                   https://api.github.com/repos/tensorflow/tensor...
# key                  https://api.github.com/repos/tensorflow/tensor...
# login                https://api.github.com/repos/tensorflow/tensor...
# name                 https://api.github.com/repos/tensorflow/tensor...
# organizations_url    https://api.github.com/repos/tensorflow/tensor...
# received_events_url  https://api.github.com/repos/tensorflow/tensor...
# repos_url            https://api.github.com/repos/tensorflow/tensor...
# site_admin           https://api.github.com/repos/tensorflow/tensor...
# spdx_id              https://api.github.com/repos/tensorflow/tensor...
# starred_url          https://api.github.com/repos/tensorflow/tensor...
# subscriptions_url    https://api.github.com/repos/tensorflow/tensor...
# type                 https://api.github.com/repos/tensorflow/tensor...
# url                  https://api.github.com/repos/tensorflow/tensor...
#
#                                                           branches_url  \
# avatar_url           https://api.github.com/repos/tensorflow/tensor...
# events_url           https://api.github.com/repos/tensorflow/tensor...
# followers_url        https://api.github.com/repos/tensorflow/tensor...
# following_url        https://api.github.com/repos/tensorflow/tensor...
# gists_url            https://api.github.com/repos/tensorflow/tensor...
# gravatar_id          https://api.github.com/repos/tensorflow/tensor...
# html_url             https://api.github.com/repos/tensorflow/tensor...
# id                   https://api.github.com/repos/tensorflow/tensor...
# key                  https://api.github.com/repos/tensorflow/tensor...
# login                https://api.github.com/repos/tensorflow/tensor...
# name                 https://api.github.com/repos/tensorflow/tensor...
# organizations_url    https://api.github.com/repos/tensorflow/tensor...
# received_events_url  https://api.github.com/repos/tensorflow/tensor...
# repos_url            https://api.github.com/repos/tensorflow/tensor...
# site_admin           https://api.github.com/repos/tensorflow/tensor...
# spdx_id              https://api.github.com/repos/tensorflow/tensor...
# starred_url          https://api.github.com/repos/tensorflow/tensor...
# subscriptions_url    https://api.github.com/repos/tensorflow/tensor...
# type                 https://api.github.com/repos/tensorflow/tensor...
# url                  https://api.github.com/repos/tensorflow/tensor...
#
#                                                         clone_url  \
# avatar_url           https://github.com/tensorflow/tensorflow.git
# events_url           https://github.com/tensorflow/tensorflow.git
# followers_url        https://github.com/tensorflow/tensorflow.git
# following_url        https://github.com/tensorflow/tensorflow.git
# gists_url            https://github.com/tensorflow/tensorflow.git
# gravatar_id          https://github.com/tensorflow/tensorflow.git
# html_url             https://github.com/tensorflow/tensorflow.git
# id                   https://github.com/tensorflow/tensorflow.git
# key                  https://github.com/tensorflow/tensorflow.git
# login                https://github.com/tensorflow/tensorflow.git
# name                 https://github.com/tensorflow/tensorflow.git
# organizations_url    https://github.com/tensorflow/tensorflow.git
# received_events_url  https://github.com/tensorflow/tensorflow.git
# repos_url            https://github.com/tensorflow/tensorflow.git
# site_admin           https://github.com/tensorflow/tensorflow.git
# spdx_id              https://github.com/tensorflow/tensorflow.git
# starred_url          https://github.com/tensorflow/tensorflow.git
# subscriptions_url    https://github.com/tensorflow/tensorflow.git
# type                 https://github.com/tensorflow/tensorflow.git
# url                  https://github.com/tensorflow/tensorflow.git
#
#                                                      collaborators_url  \
# avatar_url           https://api.github.com/repos/tensorflow/tensor...
# events_url           https://api.github.com/repos/tensorflow/tensor...
# followers_url        https://api.github.com/repos/tensorflow/tensor...
# following_url        https://api.github.com/repos/tensorflow/tensor...
# gists_url            https://api.github.com/repos/tensorflow/tensor...
# gravatar_id          https://api.github.com/repos/tensorflow/tensor...
# html_url             https://api.github.com/repos/tensorflow/tensor...
# id                   https://api.github.com/repos/tensorflow/tensor...
# key                  https://api.github.com/repos/tensorflow/tensor...
# login                https://api.github.com/repos/tensorflow/tensor...
# name                 https://api.github.com/repos/tensorflow/tensor...
# organizations_url    https://api.github.com/repos/tensorflow/tensor...
# received_events_url  https://api.github.com/repos/tensorflow/tensor...
# repos_url            https://api.github.com/repos/tensorflow/tensor...
# site_admin           https://api.github.com/repos/tensorflow/tensor...
# spdx_id              https://api.github.com/repos/tensorflow/tensor...
# starred_url          https://api.github.com/repos/tensorflow/tensor...
# subscriptions_url    https://api.github.com/repos/tensorflow/tensor...
# type                 https://api.github.com/repos/tensorflow/tensor...
# url                  https://api.github.com/repos/tensorflow/tensor...
#
#                                                           comments_url  \
# avatar_url           https://api.github.com/repos/tensorflow/tensor...
# events_url           https://api.github.com/repos/tensorflow/tensor...
# followers_url        https://api.github.com/repos/tensorflow/tensor...
# following_url        https://api.github.com/repos/tensorflow/tensor...
# gists_url            https://api.github.com/repos/tensorflow/tensor...
# gravatar_id          https://api.github.com/repos/tensorflow/tensor...
# html_url             https://api.github.com/repos/tensorflow/tensor...
# id                   https://api.github.com/repos/tensorflow/tensor...
# key                  https://api.github.com/repos/tensorflow/tensor...
# login                https://api.github.com/repos/tensorflow/tensor...
# name                 https://api.github.com/repos/tensorflow/tensor...
# organizations_url    https://api.github.com/repos/tensorflow/tensor...
# received_events_url  https://api.github.com/repos/tensorflow/tensor...
# repos_url            https://api.github.com/repos/tensorflow/tensor...
# site_admin           https://api.github.com/repos/tensorflow/tensor...
# spdx_id              https://api.github.com/repos/tensorflow/tensor...
# starred_url          https://api.github.com/repos/tensorflow/tensor...
# subscriptions_url    https://api.github.com/repos/tensorflow/tensor...
# type                 https://api.github.com/repos/tensorflow/tensor...
# url                  https://api.github.com/repos/tensorflow/tensor...
#
#                                                            commits_url  \
# avatar_url           https://api.github.com/repos/tensorflow/tensor...
# events_url           https://api.github.com/repos/tensorflow/tensor...
# followers_url        https://api.github.com/repos/tensorflow/tensor...
# following_url        https://api.github.com/repos/tensorflow/tensor...
# gists_url            https://api.github.com/repos/tensorflow/tensor...
# gravatar_id          https://api.github.com/repos/tensorflow/tensor...
# html_url             https://api.github.com/repos/tensorflow/tensor...
# id                   https://api.github.com/repos/tensorflow/tensor...
# key                  https://api.github.com/repos/tensorflow/tensor...
# login                https://api.github.com/repos/tensorflow/tensor...
# name                 https://api.github.com/repos/tensorflow/tensor...
# organizations_url    https://api.github.com/repos/tensorflow/tensor...
# received_events_url  https://api.github.com/repos/tensorflow/tensor...
# repos_url            https://api.github.com/repos/tensorflow/tensor...
# site_admin           https://api.github.com/repos/tensorflow/tensor...
# spdx_id              https://api.github.com/repos/tensorflow/tensor...
# starred_url          https://api.github.com/repos/tensorflow/tensor...
# subscriptions_url    https://api.github.com/repos/tensorflow/tensor...
# type                 https://api.github.com/repos/tensorflow/tensor...
# url                  https://api.github.com/repos/tensorflow/tensor...
#
#                                                            compare_url  \
# avatar_url           https://api.github.com/repos/tensorflow/tensor...
# events_url           https://api.github.com/repos/tensorflow/tensor...
# followers_url        https://api.github.com/repos/tensorflow/tensor...
# following_url        https://api.github.com/repos/tensorflow/tensor...
# gists_url            https://api.github.com/repos/tensorflow/tensor...
# gravatar_id          https://api.github.com/repos/tensorflow/tensor...
# html_url             https://api.github.com/repos/tensorflow/tensor...
# id                   https://api.github.com/repos/tensorflow/tensor...
# key                  https://api.github.com/repos/tensorflow/tensor...
# login                https://api.github.com/repos/tensorflow/tensor...
# name                 https://api.github.com/repos/tensorflow/tensor...
# organizations_url    https://api.github.com/repos/tensorflow/tensor...
# received_events_url  https://api.github.com/repos/tensorflow/tensor...
# repos_url            https://api.github.com/repos/tensorflow/tensor...
# site_admin           https://api.github.com/repos/tensorflow/tensor...
# spdx_id              https://api.github.com/repos/tensorflow/tensor...
# starred_url          https://api.github.com/repos/tensorflow/tensor...
# subscriptions_url    https://api.github.com/repos/tensorflow/tensor...
# type                 https://api.github.com/repos/tensorflow/tensor...
# url                  https://api.github.com/repos/tensorflow/tensor...
#
#                           ...        \
# avatar_url                ...
# events_url                ...
# followers_url             ...
# following_url             ...
# gists_url                 ...
# gravatar_id               ...
# html_url                  ...
# id                        ...
# key                       ...
# login                     ...
# name                      ...
# organizations_url         ...
# received_events_url       ...
# repos_url                 ...
# site_admin                ...
# spdx_id                   ...
# starred_url               ...
# subscriptions_url         ...
# type                      ...
# url                       ...
#
#                                                        subscribers_url  \
# avatar_url           https://api.github.com/repos/tensorflow/tensor...
# events_url           https://api.github.com/repos/tensorflow/tensor...
# followers_url        https://api.github.com/repos/tensorflow/tensor...
# following_url        https://api.github.com/repos/tensorflow/tensor...
# gists_url            https://api.github.com/repos/tensorflow/tensor...
# gravatar_id          https://api.github.com/repos/tensorflow/tensor...
# html_url             https://api.github.com/repos/tensorflow/tensor...
# id                   https://api.github.com/repos/tensorflow/tensor...
# key                  https://api.github.com/repos/tensorflow/tensor...
# login                https://api.github.com/repos/tensorflow/tensor...
# name                 https://api.github.com/repos/tensorflow/tensor...
# organizations_url    https://api.github.com/repos/tensorflow/tensor...
# received_events_url  https://api.github.com/repos/tensorflow/tensor...
# repos_url            https://api.github.com/repos/tensorflow/tensor...
# site_admin           https://api.github.com/repos/tensorflow/tensor...
# spdx_id              https://api.github.com/repos/tensorflow/tensor...
# starred_url          https://api.github.com/repos/tensorflow/tensor...
# subscriptions_url    https://api.github.com/repos/tensorflow/tensor...
# type                 https://api.github.com/repos/tensorflow/tensor...
# url                  https://api.github.com/repos/tensorflow/tensor...
#
#                                                       subscription_url  \
# avatar_url           https://api.github.com/repos/tensorflow/tensor...
# events_url           https://api.github.com/repos/tensorflow/tensor...
# followers_url        https://api.github.com/repos/tensorflow/tensor...
# following_url        https://api.github.com/repos/tensorflow/tensor...
# gists_url            https://api.github.com/repos/tensorflow/tensor...
# gravatar_id          https://api.github.com/repos/tensorflow/tensor...
# html_url             https://api.github.com/repos/tensorflow/tensor...
# id                   https://api.github.com/repos/tensorflow/tensor...
# key                  https://api.github.com/repos/tensorflow/tensor...
# login                https://api.github.com/repos/tensorflow/tensor...
# name                 https://api.github.com/repos/tensorflow/tensor...
# organizations_url    https://api.github.com/repos/tensorflow/tensor...
# received_events_url  https://api.github.com/repos/tensorflow/tensor...
# repos_url            https://api.github.com/repos/tensorflow/tensor...
# site_admin           https://api.github.com/repos/tensorflow/tensor...
# spdx_id              https://api.github.com/repos/tensorflow/tensor...
# starred_url          https://api.github.com/repos/tensorflow/tensor...
# subscriptions_url    https://api.github.com/repos/tensorflow/tensor...
# type                 https://api.github.com/repos/tensorflow/tensor...
# url                  https://api.github.com/repos/tensorflow/tensor...
#
#                                                       svn_url  \
# avatar_url           https://github.com/tensorflow/tensorflow
# events_url           https://github.com/tensorflow/tensorflow
# followers_url        https://github.com/tensorflow/tensorflow
# following_url        https://github.com/tensorflow/tensorflow
# gists_url            https://github.com/tensorflow/tensorflow
# gravatar_id          https://github.com/tensorflow/tensorflow
# html_url             https://github.com/tensorflow/tensorflow
# id                   https://github.com/tensorflow/tensorflow
# key                  https://github.com/tensorflow/tensorflow
# login                https://github.com/tensorflow/tensorflow
# name                 https://github.com/tensorflow/tensorflow
# organizations_url    https://github.com/tensorflow/tensorflow
# received_events_url  https://github.com/tensorflow/tensorflow
# repos_url            https://github.com/tensorflow/tensorflow
# site_admin           https://github.com/tensorflow/tensorflow
# spdx_id              https://github.com/tensorflow/tensorflow
# starred_url          https://github.com/tensorflow/tensorflow
# subscriptions_url    https://github.com/tensorflow/tensorflow
# type                 https://github.com/tensorflow/tensorflow
# url                  https://github.com/tensorflow/tensorflow
#
#                                                               tags_url  \
# avatar_url           https://api.github.com/repos/tensorflow/tensor...
# events_url           https://api.github.com/repos/tensorflow/tensor...
# followers_url        https://api.github.com/repos/tensorflow/tensor...
# following_url        https://api.github.com/repos/tensorflow/tensor...
# gists_url            https://api.github.com/repos/tensorflow/tensor...
# gravatar_id          https://api.github.com/repos/tensorflow/tensor...
# html_url             https://api.github.com/repos/tensorflow/tensor...
# id                   https://api.github.com/repos/tensorflow/tensor...
# key                  https://api.github.com/repos/tensorflow/tensor...
# login                https://api.github.com/repos/tensorflow/tensor...
# name                 https://api.github.com/repos/tensorflow/tensor...
# organizations_url    https://api.github.com/repos/tensorflow/tensor...
# received_events_url  https://api.github.com/repos/tensorflow/tensor...
# repos_url            https://api.github.com/repos/tensorflow/tensor...
# site_admin           https://api.github.com/repos/tensorflow/tensor...
# spdx_id              https://api.github.com/repos/tensorflow/tensor...
# starred_url          https://api.github.com/repos/tensorflow/tensor...
# subscriptions_url    https://api.github.com/repos/tensorflow/tensor...
# type                 https://api.github.com/repos/tensorflow/tensor...
# url                  https://api.github.com/repos/tensorflow/tensor...
#
#                                                              teams_url  \
# avatar_url           https://api.github.com/repos/tensorflow/tensor...
# events_url           https://api.github.com/repos/tensorflow/tensor...
# followers_url        https://api.github.com/repos/tensorflow/tensor...
# following_url        https://api.github.com/repos/tensorflow/tensor...
# gists_url            https://api.github.com/repos/tensorflow/tensor...
# gravatar_id          https://api.github.com/repos/tensorflow/tensor...
# html_url             https://api.github.com/repos/tensorflow/tensor...
# id                   https://api.github.com/repos/tensorflow/tensor...
# key                  https://api.github.com/repos/tensorflow/tensor...
# login                https://api.github.com/repos/tensorflow/tensor...
# name                 https://api.github.com/repos/tensorflow/tensor...
# organizations_url    https://api.github.com/repos/tensorflow/tensor...
# received_events_url  https://api.github.com/repos/tensorflow/tensor...
# repos_url            https://api.github.com/repos/tensorflow/tensor...
# site_admin           https://api.github.com/repos/tensorflow/tensor...
# spdx_id              https://api.github.com/repos/tensorflow/tensor...
# starred_url          https://api.github.com/repos/tensorflow/tensor...
# subscriptions_url    https://api.github.com/repos/tensorflow/tensor...
# type                 https://api.github.com/repos/tensorflow/tensor...
# url                  https://api.github.com/repos/tensorflow/tensor...
#
#                                                              trees_url  \
# avatar_url           https://api.github.com/repos/tensorflow/tensor...
# events_url           https://api.github.com/repos/tensorflow/tensor...
# followers_url        https://api.github.com/repos/tensorflow/tensor...
# following_url        https://api.github.com/repos/tensorflow/tensor...
# gists_url            https://api.github.com/repos/tensorflow/tensor...
# gravatar_id          https://api.github.com/repos/tensorflow/tensor...
# html_url             https://api.github.com/repos/tensorflow/tensor...
# id                   https://api.github.com/repos/tensorflow/tensor...
# key                  https://api.github.com/repos/tensorflow/tensor...
# login                https://api.github.com/repos/tensorflow/tensor...
# name                 https://api.github.com/repos/tensorflow/tensor...
# organizations_url    https://api.github.com/repos/tensorflow/tensor...
# received_events_url  https://api.github.com/repos/tensorflow/tensor...
# repos_url            https://api.github.com/repos/tensorflow/tensor...
# site_admin           https://api.github.com/repos/tensorflow/tensor...
# spdx_id              https://api.github.com/repos/tensorflow/tensor...
# starred_url          https://api.github.com/repos/tensorflow/tensor...
# subscriptions_url    https://api.github.com/repos/tensorflow/tensor...
# type                 https://api.github.com/repos/tensorflow/tensor...
# url                  https://api.github.com/repos/tensorflow/tensor...
#
#                              updated_at  \
# avatar_url          2018-04-15 23:57:53
# events_url          2018-04-15 23:57:53
# followers_url       2018-04-15 23:57:53
# following_url       2018-04-15 23:57:53
# gists_url           2018-04-15 23:57:53
# gravatar_id         2018-04-15 23:57:53
# html_url            2018-04-15 23:57:53
# id                  2018-04-15 23:57:53
# key                 2018-04-15 23:57:53
# login               2018-04-15 23:57:53
# name                2018-04-15 23:57:53
# organizations_url   2018-04-15 23:57:53
# received_events_url 2018-04-15 23:57:53
# repos_url           2018-04-15 23:57:53
# site_admin          2018-04-15 23:57:53
# spdx_id             2018-04-15 23:57:53
# starred_url         2018-04-15 23:57:53
# subscriptions_url   2018-04-15 23:57:53
# type                2018-04-15 23:57:53
# url                 2018-04-15 23:57:53
#
#                                                                    url  \
# avatar_url           https://api.github.com/repos/tensorflow/tensor...
# events_url           https://api.github.com/repos/tensorflow/tensor...
# followers_url        https://api.github.com/repos/tensorflow/tensor...
# following_url        https://api.github.com/repos/tensorflow/tensor...
# gists_url            https://api.github.com/repos/tensorflow/tensor...
# gravatar_id          https://api.github.com/repos/tensorflow/tensor...
# html_url             https://api.github.com/repos/tensorflow/tensor...
# id                   https://api.github.com/repos/tensorflow/tensor...
# key                  https://api.github.com/repos/tensorflow/tensor...
# login                https://api.github.com/repos/tensorflow/tensor...
# name                 https://api.github.com/repos/tensorflow/tensor...
# organizations_url    https://api.github.com/repos/tensorflow/tensor...
# received_events_url  https://api.github.com/repos/tensorflow/tensor...
# repos_url            https://api.github.com/repos/tensorflow/tensor...
# site_admin           https://api.github.com/repos/tensorflow/tensor...
# spdx_id              https://api.github.com/repos/tensorflow/tensor...
# starred_url          https://api.github.com/repos/tensorflow/tensor...
# subscriptions_url    https://api.github.com/repos/tensorflow/tensor...
# type                 https://api.github.com/repos/tensorflow/tensor...
# url                  https://api.github.com/repos/tensorflow/tensor...
#
#                      watchers  watchers_count
# avatar_url              96378           96378
# events_url              96378           96378
# followers_url           96378           96378
# following_url           96378           96378
# gists_url               96378           96378
# gravatar_id             96378           96378
# html_url                96378           96378
# id                      96378           96378
# key                     96378           96378
# login                   96378           96378
# name                    96378           96378
# organizations_url       96378           96378
# received_events_url     96378           96378
# repos_url               96378           96378
# site_admin              96378           96378
# spdx_id                 96378           96378
# starred_url             96378           96378
# subscriptions_url       96378           96378
# type                    96378           96378
# url                     96378           96378
#
# [20 rows x 74 columns]

# %%
#'https://api.github.com/repos/tensorflow/tensorflow/contributors'
res = requests.get('https://api.github.com/repos/tensorflow/tensorflow/contributors?anon=1&page=45')

# %%
len(res.json())
res.json()
# Out:
# {'documentation_url': 'https://developer.github.com/v3',
#  'message': 'Bad credentials'}

# %%
import pandas as pd

# %%
res1.append(pd.read_json(res))
# Out:
#                                            avatar_url  contributions  \
# 0                                                 NaN              1
# 1                                                 NaN              1
# 2                                                 NaN              1
# 3                                                 NaN              1
# 4                                                 NaN              1
# 5                                                 NaN              1
# 6                                                 NaN              1
# 7                                                 NaN              1
# 8                                                 NaN              1
# 9                                                 NaN              1
# 10                                                NaN              1
# 11                                                NaN              1
# 12                                                NaN              1
# 13                                                NaN              1
# 14                                                NaN              1
# 15                                                NaN              1
# 16                                                NaN              1
# 17                                                NaN              1
# 18                                                NaN              1
# 19                                                NaN              1
# 20                                                NaN              1
# 21                                                NaN              1
# 22                                                NaN              1
# 23                                                NaN              1
# 24                                                NaN              1
# 25                                                NaN              1
# 26                                                NaN              1
# 27                                                NaN              1
# 28                                                NaN              1
# 29                                                NaN              1
# 0   https://avatars3.githubusercontent.com/u/71025...           2148
# 1   https://avatars0.githubusercontent.com/u/11006...            197
# 2   https://avatars3.githubusercontent.com/u/14060...            106
# 3   https://avatars2.githubusercontent.com/u/44455...             87
# 4   https://avatars3.githubusercontent.com/u/39024...             65
# 5   https://avatars1.githubusercontent.com/u/34625...             63
# 6   https://avatars3.githubusercontent.com/u/12389...             62
# 7   https://avatars0.githubusercontent.com/u/32655...             53
# 8   https://avatars3.githubusercontent.com/u/14494...             37
# 9   https://avatars3.githubusercontent.com/u/71217...             35
# 10  https://avatars1.githubusercontent.com/u/14356...             32
# 11  https://avatars0.githubusercontent.com/u/82676...             30
# 12  https://avatars3.githubusercontent.com/u/89765...             26
# 13  https://avatars1.githubusercontent.com/u/5733?v=4             26
# 14  https://avatars1.githubusercontent.com/u/55744...             24
# 15  https://avatars2.githubusercontent.com/u/38025...             24
# 16  https://avatars2.githubusercontent.com/u/50660...             21
# 17  https://avatars3.githubusercontent.com/u/31510...             17
# 18                                                NaN             17
# 19  https://avatars0.githubusercontent.com/u/60954...             17
# 20  https://avatars2.githubusercontent.com/u/55539...             16
# 21  https://avatars3.githubusercontent.com/u/15959...             15
# 22  https://avatars3.githubusercontent.com/u/38263...             15
# 23  https://avatars1.githubusercontent.com/u/20862...             15
# 24  https://avatars1.githubusercontent.com/u/21106...             14
# 25  https://avatars0.githubusercontent.com/u/38176...             14
# 26  https://avatars2.githubusercontent.com/u/10293...             14
# 27  https://avatars0.githubusercontent.com/u/65050...             13
# 28  https://avatars1.githubusercontent.com/u/65680...             13
# 29  https://avatars1.githubusercontent.com/u/12891...             13
#
#                                       email  \
# 0   ramon-oliveira@users.noreply.github.com
# 1                         rks1986@gmail.com
# 2                      reid@reidsanders.net
# 3              reiichiro.s.nakano@gmail.com
# 4                     averybigant@gmail.com
# 5                           rl403@cam.ac.uk
# 6                          richard@relh.net
# 7                  rlphillips@haverford.edu
# 8                     rishikksh20@gmail.com
# 9      ritwikgupta@users.noreply.github.com
# 10                    rob.grzesik@gmail.com
# 11                     robert.sim@gmail.com
# 12                         royopa@gmail.com
# 13                roland.swingler@gmail.com
# 14                roman.prokofyev@gmail.com
# 15                      poyan.ron@gmail.com
# 16                         xljroy@gmail.com
# 17                       00ruishu@gmail.com
# 18          russ09@users.noreply.github.com
# 19                      rustymina@gmail.com
# 20                      rsoklaski@gmail.com
# 21                 janne.dc.ib.sa@gmail.com
# 22                  ryohei.kuroki@gmail.com
# 23                  honda00888005@gmail.com
# 24                       zryuichi@gmail.com
# 25                       sm774113@gmail.com
# 26         pse1202@users.noreply.github.com
# 27             saul.vargassandoval@asos.com
# 28          seanbe@users.noreply.github.com
# 29                      ssall@alumni.nd.edu
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
# 10                                      NaN
# 11                                      NaN
# 12                                      NaN
# 13                                      NaN
# 14                                      NaN
# 15                                      NaN
# 16                                      NaN
# 17                                      NaN
# 18                         lchen3@gmail.com
# 19                                      NaN
# 20                                      NaN
# 21                                      NaN
# 22                                      NaN
# 23                                      NaN
# 24                                      NaN
# 25                                      NaN
# 26                                      NaN
# 27                                      NaN
# 28                                      NaN
# 29                                      NaN
#
#                                            events_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 0   https://api.github.com/users/fchollet/events{/...
# 1   https://api.github.com/users/farizrahman4u/eve...
# 2   https://api.github.com/users/ozabluda/events{/...
# 3   https://api.github.com/users/taehoonlee/events...
# 4   https://api.github.com/users/EderSantana/event...
# 5   https://api.github.com/users/maxpumperla/event...
# 6   https://api.github.com/users/phreeza/events{/p...
# 7   https://api.github.com/users/wxs/events{/privacy}
# 8   https://api.github.com/users/the-moliver/event...
# 9   https://api.github.com/users/nzw0301/events{/p...
# 10  https://api.github.com/users/matsuyamax/events...
# 11  https://api.github.com/users/tdhd/events{/priv...
# 12  https://api.github.com/users/Dref360/events{/p...
# 13  https://api.github.com/users/jfsantos/events{/...
# 14  https://api.github.com/users/ahundt/events{/pr...
# 15  https://api.github.com/users/myutwo150/events{...
# 16  https://api.github.com/users/julienr/events{/p...
# 17  https://api.github.com/users/gvtulder/events{/...
# 18                                                NaN
# 19  https://api.github.com/users/tleeuwenburg/even...
# 20  https://api.github.com/users/tboquet/events{/p...
# 21  https://api.github.com/users/carlthome/events{...
# 22  https://api.github.com/users/lukedeo/events{/p...
# 23  https://api.github.com/users/olegsinyavskiy/ev...
# 24  https://api.github.com/users/abhaikollara/even...
# 25  https://api.github.com/users/yaringal/events{/...
# 26  https://api.github.com/users/jihobak/events{/p...
# 27  https://api.github.com/users/Danielhiversen/ev...
# 28  https://api.github.com/users/jeammimi/events{/...
# 29  https://api.github.com/users/gabrieldemarmiess...
#
#                                         followers_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 0     https://api.github.com/users/fchollet/followers
# 1   https://api.github.com/users/farizrahman4u/fol...
# 2     https://api.github.com/users/ozabluda/followers
# 3   https://api.github.com/users/taehoonlee/followers
# 4   https://api.github.com/users/EderSantana/follo...
# 5   https://api.github.com/users/maxpumperla/follo...
# 6      https://api.github.com/users/phreeza/followers
# 7          https://api.github.com/users/wxs/followers
# 8   https://api.github.com/users/the-moliver/follo...
# 9      https://api.github.com/users/nzw0301/followers
# 10  https://api.github.com/users/matsuyamax/followers
# 11        https://api.github.com/users/tdhd/followers
# 12     https://api.github.com/users/Dref360/followers
# 13    https://api.github.com/users/jfsantos/followers
# 14      https://api.github.com/users/ahundt/followers
# 15   https://api.github.com/users/myutwo150/followers
# 16     https://api.github.com/users/julienr/followers
# 17    https://api.github.com/users/gvtulder/followers
# 18                                                NaN
# 19  https://api.github.com/users/tleeuwenburg/foll...
# 20     https://api.github.com/users/tboquet/followers
# 21   https://api.github.com/users/carlthome/followers
# 22     https://api.github.com/users/lukedeo/followers
# 23  https://api.github.com/users/olegsinyavskiy/fo...
# 24  https://api.github.com/users/abhaikollara/foll...
# 25    https://api.github.com/users/yaringal/followers
# 26     https://api.github.com/users/jihobak/followers
# 27  https://api.github.com/users/Danielhiversen/fo...
# 28    https://api.github.com/users/jeammimi/followers
# 29  https://api.github.com/users/gabrieldemarmiess...
#
#                                         following_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 0   https://api.github.com/users/fchollet/followin...
# 1   https://api.github.com/users/farizrahman4u/fol...
# 2   https://api.github.com/users/ozabluda/followin...
# 3   https://api.github.com/users/taehoonlee/follow...
# 4   https://api.github.com/users/EderSantana/follo...
# 5   https://api.github.com/users/maxpumperla/follo...
# 6   https://api.github.com/users/phreeza/following...
# 7   https://api.github.com/users/wxs/following{/ot...
# 8   https://api.github.com/users/the-moliver/follo...
# 9   https://api.github.com/users/nzw0301/following...
# 10  https://api.github.com/users/matsuyamax/follow...
# 11  https://api.github.com/users/tdhd/following{/o...
# 12  https://api.github.com/users/Dref360/following...
# 13  https://api.github.com/users/jfsantos/followin...
# 14  https://api.github.com/users/ahundt/following{...
# 15  https://api.github.com/users/myutwo150/followi...
# 16  https://api.github.com/users/julienr/following...
# 17  https://api.github.com/users/gvtulder/followin...
# 18                                                NaN
# 19  https://api.github.com/users/tleeuwenburg/foll...
# 20  https://api.github.com/users/tboquet/following...
# 21  https://api.github.com/users/carlthome/followi...
# 22  https://api.github.com/users/lukedeo/following...
# 23  https://api.github.com/users/olegsinyavskiy/fo...
# 24  https://api.github.com/users/abhaikollara/foll...
# 25  https://api.github.com/users/yaringal/followin...
# 26  https://api.github.com/users/jihobak/following...
# 27  https://api.github.com/users/Danielhiversen/fo...
# 28  https://api.github.com/users/jeammimi/followin...
# 29  https://api.github.com/users/gabrieldemarmiess...
#
#                                             gists_url gravatar_id  \
# 0                                                 NaN         NaN
# 1                                                 NaN         NaN
# 2                                                 NaN         NaN
# 3                                                 NaN         NaN
# 4                                                 NaN         NaN
# 5                                                 NaN         NaN
# 6                                                 NaN         NaN
# 7                                                 NaN         NaN
# 8                                                 NaN         NaN
# 9                                                 NaN         NaN
# 10                                                NaN         NaN
# 11                                                NaN         NaN
# 12                                                NaN         NaN
# 13                                                NaN         NaN
# 14                                                NaN         NaN
# 15                                                NaN         NaN
# 16                                                NaN         NaN
# 17                                                NaN         NaN
# 18                                                NaN         NaN
# 19                                                NaN         NaN
# 20                                                NaN         NaN
# 21                                                NaN         NaN
# 22                                                NaN         NaN
# 23                                                NaN         NaN
# 24                                                NaN         NaN
# 25                                                NaN         NaN
# 26                                                NaN         NaN
# 27                                                NaN         NaN
# 28                                                NaN         NaN
# 29                                                NaN         NaN
# 0   https://api.github.com/users/fchollet/gists{/g...
# 1   https://api.github.com/users/farizrahman4u/gis...
# 2   https://api.github.com/users/ozabluda/gists{/g...
# 3   https://api.github.com/users/taehoonlee/gists{...
# 4   https://api.github.com/users/EderSantana/gists...
# 5   https://api.github.com/users/maxpumperla/gists...
# 6   https://api.github.com/users/phreeza/gists{/gi...
# 7    https://api.github.com/users/wxs/gists{/gist_id}
# 8   https://api.github.com/users/the-moliver/gists...
# 9   https://api.github.com/users/nzw0301/gists{/gi...
# 10  https://api.github.com/users/matsuyamax/gists{...
# 11  https://api.github.com/users/tdhd/gists{/gist_id}
# 12  https://api.github.com/users/Dref360/gists{/gi...
# 13  https://api.github.com/users/jfsantos/gists{/g...
# 14  https://api.github.com/users/ahundt/gists{/gis...
# 15  https://api.github.com/users/myutwo150/gists{/...
# 16  https://api.github.com/users/julienr/gists{/gi...
# 17  https://api.github.com/users/gvtulder/gists{/g...
# 18                                                NaN         NaN
# 19  https://api.github.com/users/tleeuwenburg/gist...
# 20  https://api.github.com/users/tboquet/gists{/gi...
# 21  https://api.github.com/users/carlthome/gists{/...
# 22  https://api.github.com/users/lukedeo/gists{/gi...
# 23  https://api.github.com/users/olegsinyavskiy/gi...
# 24  https://api.github.com/users/abhaikollara/gist...
# 25  https://api.github.com/users/yaringal/gists{/g...
# 26  https://api.github.com/users/jihobak/gists{/gi...
# 27  https://api.github.com/users/Danielhiversen/gi...
# 28  https://api.github.com/users/jeammimi/gists{/g...
# 29  https://api.github.com/users/gabrieldemarmiess...
#
#                                  html_url          id               login  \
# 0                                     NaN         NaN                 NaN
# 1                                     NaN         NaN                 NaN
# 2                                     NaN         NaN                 NaN
# 3                                     NaN         NaN                 NaN
# 4                                     NaN         NaN                 NaN
# 5                                     NaN         NaN                 NaN
# 6                                     NaN         NaN                 NaN
# 7                                     NaN         NaN                 NaN
# 8                                     NaN         NaN                 NaN
# 9                                     NaN         NaN                 NaN
# 10                                    NaN         NaN                 NaN
# 11                                    NaN         NaN                 NaN
# 12                                    NaN         NaN                 NaN
# 13                                    NaN         NaN                 NaN
# 14                                    NaN         NaN                 NaN
# 15                                    NaN         NaN                 NaN
# 16                                    NaN         NaN                 NaN
# 17                                    NaN         NaN                 NaN
# 18                                    NaN         NaN                 NaN
# 19                                    NaN         NaN                 NaN
# 20                                    NaN         NaN                 NaN
# 21                                    NaN         NaN                 NaN
# 22                                    NaN         NaN                 NaN
# 23                                    NaN         NaN                 NaN
# 24                                    NaN         NaN                 NaN
# 25                                    NaN         NaN                 NaN
# 26                                    NaN         NaN                 NaN
# 27                                    NaN         NaN                 NaN
# 28                                    NaN         NaN                 NaN
# 29                                    NaN         NaN                 NaN
# 0             https://github.com/fchollet    710255.0            fchollet
# 1        https://github.com/farizrahman4u  11006006.0       farizrahman4u
# 2             https://github.com/ozabluda  14060629.0            ozabluda
# 3           https://github.com/taehoonlee   4445535.0          taehoonlee
# 4          https://github.com/EderSantana   3902480.0         EderSantana
# 5          https://github.com/maxpumperla   3462566.0         maxpumperla
# 6              https://github.com/phreeza    123894.0             phreeza
# 7                  https://github.com/wxs    326559.0                 wxs
# 8          https://github.com/the-moliver    144949.0         the-moliver
# 9              https://github.com/nzw0301   7121753.0             nzw0301
# 10          https://github.com/matsuyamax  14356347.0          matsuyamax
# 11                https://github.com/tdhd   8267636.0                tdhd
# 12             https://github.com/Dref360   8976546.0             Dref360
# 13            https://github.com/jfsantos      5733.0            jfsantos
# 14              https://github.com/ahundt     55744.0              ahundt
# 15           https://github.com/myutwo150  38025301.0           myutwo150
# 16             https://github.com/julienr    506602.0             julienr
# 17            https://github.com/gvtulder     31510.0            gvtulder
# 18                                    NaN         NaN                 NaN
# 19        https://github.com/tleeuwenburg     60954.0        tleeuwenburg
# 20             https://github.com/tboquet   5553901.0             tboquet
# 21           https://github.com/carlthome   1595907.0           carlthome
# 22             https://github.com/lukedeo   3826382.0             lukedeo
# 23      https://github.com/olegsinyavskiy   2086260.0      olegsinyavskiy
# 24        https://github.com/abhaikollara  21106717.0        abhaikollara
# 25            https://github.com/yaringal   3817641.0            yaringal
# 26             https://github.com/jihobak  10293523.0             jihobak
# 27      https://github.com/Danielhiversen    650502.0      Danielhiversen
# 28            https://github.com/jeammimi   6568042.0            jeammimi
# 29  https://github.com/gabrieldemarmiesse  12891691.0  gabrieldemarmiesse
#
#                    name                                  organizations_url  \
# 0     Ramon de Oliveira                                                NaN
# 1      Ravi Kant Sharma                                                NaN
# 2          Reid Sanders                                                NaN
# 3      Reiichiro Nakano                                                NaN
# 4              Renbi.YU                                                NaN
# 5      Rich P. I. Lewis                                                NaN
# 6       Richard Higgins                                                NaN
# 7   Richard L. Phillips                                                NaN
# 8             Rishikesh                                                NaN
# 9          Ritwik Gupta                                                NaN
# 10       Robert Grzesik                                                NaN
# 11           Robert Sim                                                NaN
# 12        Rodrigo Prado                                                NaN
# 13      Roland Swingler                                                NaN
# 14      Roman Prokofyev                                                NaN
# 15        Rong Yuanzhen                                                NaN
# 16              Roy Xue                                                NaN
# 17              Rui Shu                                                NaN
# 18               Russ09                                                NaN
# 19                Rusty                                                NaN
# 20                 Ryan                                                NaN
# 21          Ryo ASAKURA                                                NaN
# 22        Ryohei Kuroki                                                NaN
# 23         RyosukeHonda                                                NaN
# 24     Ryuichi YAMAMOTO                                                NaN
# 25               Sadegh                                                NaN
# 26         Sangeon Park                                                NaN
# 27                 Saúl                                                NaN
# 28         Sean Löfgren                                                NaN
# 29            Sean Sall                                                NaN
# 0                   NaN         https://api.github.com/users/fchollet/orgs
# 1                   NaN    https://api.github.com/users/farizrahman4u/orgs
# 2                   NaN         https://api.github.com/users/ozabluda/orgs
# 3                   NaN       https://api.github.com/users/taehoonlee/orgs
# 4                   NaN      https://api.github.com/users/EderSantana/orgs
# 5                   NaN      https://api.github.com/users/maxpumperla/orgs
# 6                   NaN          https://api.github.com/users/phreeza/orgs
# 7                   NaN              https://api.github.com/users/wxs/orgs
# 8                   NaN      https://api.github.com/users/the-moliver/orgs
# 9                   NaN          https://api.github.com/users/nzw0301/orgs
# 10                  NaN       https://api.github.com/users/matsuyamax/orgs
# 11                  NaN             https://api.github.com/users/tdhd/orgs
# 12                  NaN          https://api.github.com/users/Dref360/orgs
# 13                  NaN         https://api.github.com/users/jfsantos/orgs
# 14                  NaN           https://api.github.com/users/ahundt/orgs
# 15                  NaN        https://api.github.com/users/myutwo150/orgs
# 16                  NaN          https://api.github.com/users/julienr/orgs
# 17                  NaN         https://api.github.com/users/gvtulder/orgs
# 18            Leon Chen                                                NaN
# 19                  NaN     https://api.github.com/users/tleeuwenburg/orgs
# 20                  NaN          https://api.github.com/users/tboquet/orgs
# 21                  NaN        https://api.github.com/users/carlthome/orgs
# 22                  NaN          https://api.github.com/users/lukedeo/orgs
# 23                  NaN   https://api.github.com/users/olegsinyavskiy/orgs
# 24                  NaN     https://api.github.com/users/abhaikollara/orgs
# 25                  NaN         https://api.github.com/users/yaringal/orgs
# 26                  NaN          https://api.github.com/users/jihobak/orgs
# 27                  NaN   https://api.github.com/users/Danielhiversen/orgs
# 28                  NaN         https://api.github.com/users/jeammimi/orgs
# 29                  NaN  https://api.github.com/users/gabrieldemarmiess...
#
#                                   received_events_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 0   https://api.github.com/users/fchollet/received...
# 1   https://api.github.com/users/farizrahman4u/rec...
# 2   https://api.github.com/users/ozabluda/received...
# 3   https://api.github.com/users/taehoonlee/receiv...
# 4   https://api.github.com/users/EderSantana/recei...
# 5   https://api.github.com/users/maxpumperla/recei...
# 6   https://api.github.com/users/phreeza/received_...
# 7    https://api.github.com/users/wxs/received_events
# 8   https://api.github.com/users/the-moliver/recei...
# 9   https://api.github.com/users/nzw0301/received_...
# 10  https://api.github.com/users/matsuyamax/receiv...
# 11  https://api.github.com/users/tdhd/received_events
# 12  https://api.github.com/users/Dref360/received_...
# 13  https://api.github.com/users/jfsantos/received...
# 14  https://api.github.com/users/ahundt/received_e...
# 15  https://api.github.com/users/myutwo150/receive...
# 16  https://api.github.com/users/julienr/received_...
# 17  https://api.github.com/users/gvtulder/received...
# 18                                                NaN
# 19  https://api.github.com/users/tleeuwenburg/rece...
# 20  https://api.github.com/users/tboquet/received_...
# 21  https://api.github.com/users/carlthome/receive...
# 22  https://api.github.com/users/lukedeo/received_...
# 23  https://api.github.com/users/olegsinyavskiy/re...
# 24  https://api.github.com/users/abhaikollara/rece...
# 25  https://api.github.com/users/yaringal/received...
# 26  https://api.github.com/users/jihobak/received_...
# 27  https://api.github.com/users/Danielhiversen/re...
# 28  https://api.github.com/users/jeammimi/received...
# 29  https://api.github.com/users/gabrieldemarmiess...
#
#                                             repos_url  site_admin  \
# 0                                                 NaN         NaN
# 1                                                 NaN         NaN
# 2                                                 NaN         NaN
# 3                                                 NaN         NaN
# 4                                                 NaN         NaN
# 5                                                 NaN         NaN
# 6                                                 NaN         NaN
# 7                                                 NaN         NaN
# 8                                                 NaN         NaN
# 9                                                 NaN         NaN
# 10                                                NaN         NaN
# 11                                                NaN         NaN
# 12                                                NaN         NaN
# 13                                                NaN         NaN
# 14                                                NaN         NaN
# 15                                                NaN         NaN
# 16                                                NaN         NaN
# 17                                                NaN         NaN
# 18                                                NaN         NaN
# 19                                                NaN         NaN
# 20                                                NaN         NaN
# 21                                                NaN         NaN
# 22                                                NaN         NaN
# 23                                                NaN         NaN
# 24                                                NaN         NaN
# 25                                                NaN         NaN
# 26                                                NaN         NaN
# 27                                                NaN         NaN
# 28                                                NaN         NaN
# 29                                                NaN         NaN
# 0         https://api.github.com/users/fchollet/repos         0.0
# 1    https://api.github.com/users/farizrahman4u/repos         0.0
# 2         https://api.github.com/users/ozabluda/repos         0.0
# 3       https://api.github.com/users/taehoonlee/repos         0.0
# 4      https://api.github.com/users/EderSantana/repos         0.0
# 5      https://api.github.com/users/maxpumperla/repos         0.0
# 6          https://api.github.com/users/phreeza/repos         0.0
# 7              https://api.github.com/users/wxs/repos         0.0
# 8      https://api.github.com/users/the-moliver/repos         0.0
# 9          https://api.github.com/users/nzw0301/repos         0.0
# 10      https://api.github.com/users/matsuyamax/repos         0.0
# 11            https://api.github.com/users/tdhd/repos         0.0
# 12         https://api.github.com/users/Dref360/repos         0.0
# 13        https://api.github.com/users/jfsantos/repos         0.0
# 14          https://api.github.com/users/ahundt/repos         0.0
# 15       https://api.github.com/users/myutwo150/repos         0.0
# 16         https://api.github.com/users/julienr/repos         0.0
# 17        https://api.github.com/users/gvtulder/repos         0.0
# 18                                                NaN         NaN
# 19    https://api.github.com/users/tleeuwenburg/repos         0.0
# 20         https://api.github.com/users/tboquet/repos         0.0
# 21       https://api.github.com/users/carlthome/repos         0.0
# 22         https://api.github.com/users/lukedeo/repos         0.0
# 23  https://api.github.com/users/olegsinyavskiy/repos         0.0
# 24    https://api.github.com/users/abhaikollara/repos         0.0
# 25        https://api.github.com/users/yaringal/repos         0.0
# 26         https://api.github.com/users/jihobak/repos         0.0
# 27  https://api.github.com/users/Danielhiversen/repos         0.0
# 28        https://api.github.com/users/jeammimi/repos         0.0
# 29  https://api.github.com/users/gabrieldemarmiess...         0.0
#
#                                           starred_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 0   https://api.github.com/users/fchollet/starred{...
# 1   https://api.github.com/users/farizrahman4u/sta...
# 2   https://api.github.com/users/ozabluda/starred{...
# 3   https://api.github.com/users/taehoonlee/starre...
# 4   https://api.github.com/users/EderSantana/starr...
# 5   https://api.github.com/users/maxpumperla/starr...
# 6   https://api.github.com/users/phreeza/starred{/...
# 7   https://api.github.com/users/wxs/starred{/owne...
# 8   https://api.github.com/users/the-moliver/starr...
# 9   https://api.github.com/users/nzw0301/starred{/...
# 10  https://api.github.com/users/matsuyamax/starre...
# 11  https://api.github.com/users/tdhd/starred{/own...
# 12  https://api.github.com/users/Dref360/starred{/...
# 13  https://api.github.com/users/jfsantos/starred{...
# 14  https://api.github.com/users/ahundt/starred{/o...
# 15  https://api.github.com/users/myutwo150/starred...
# 16  https://api.github.com/users/julienr/starred{/...
# 17  https://api.github.com/users/gvtulder/starred{...
# 18                                                NaN
# 19  https://api.github.com/users/tleeuwenburg/star...
# 20  https://api.github.com/users/tboquet/starred{/...
# 21  https://api.github.com/users/carlthome/starred...
# 22  https://api.github.com/users/lukedeo/starred{/...
# 23  https://api.github.com/users/olegsinyavskiy/st...
# 24  https://api.github.com/users/abhaikollara/star...
# 25  https://api.github.com/users/yaringal/starred{...
# 26  https://api.github.com/users/jihobak/starred{/...
# 27  https://api.github.com/users/Danielhiversen/st...
# 28  https://api.github.com/users/jeammimi/starred{...
# 29  https://api.github.com/users/gabrieldemarmiess...
#
#                                     subscriptions_url       type  \
# 0                                                 NaN  Anonymous
# 1                                                 NaN  Anonymous
# 2                                                 NaN  Anonymous
# 3                                                 NaN  Anonymous
# 4                                                 NaN  Anonymous
# 5                                                 NaN  Anonymous
# 6                                                 NaN  Anonymous
# 7                                                 NaN  Anonymous
# 8                                                 NaN  Anonymous
# 9                                                 NaN  Anonymous
# 10                                                NaN  Anonymous
# 11                                                NaN  Anonymous
# 12                                                NaN  Anonymous
# 13                                                NaN  Anonymous
# 14                                                NaN  Anonymous
# 15                                                NaN  Anonymous
# 16                                                NaN  Anonymous
# 17                                                NaN  Anonymous
# 18                                                NaN  Anonymous
# 19                                                NaN  Anonymous
# 20                                                NaN  Anonymous
# 21                                                NaN  Anonymous
# 22                                                NaN  Anonymous
# 23                                                NaN  Anonymous
# 24                                                NaN  Anonymous
# 25                                                NaN  Anonymous
# 26                                                NaN  Anonymous
# 27                                                NaN  Anonymous
# 28                                                NaN  Anonymous
# 29                                                NaN  Anonymous
# 0   https://api.github.com/users/fchollet/subscrip...       User
# 1   https://api.github.com/users/farizrahman4u/sub...       User
# 2   https://api.github.com/users/ozabluda/subscrip...       User
# 3   https://api.github.com/users/taehoonlee/subscr...       User
# 4   https://api.github.com/users/EderSantana/subsc...       User
# 5   https://api.github.com/users/maxpumperla/subsc...       User
# 6   https://api.github.com/users/phreeza/subscript...       User
# 7      https://api.github.com/users/wxs/subscriptions       User
# 8   https://api.github.com/users/the-moliver/subsc...       User
# 9   https://api.github.com/users/nzw0301/subscript...       User
# 10  https://api.github.com/users/matsuyamax/subscr...       User
# 11    https://api.github.com/users/tdhd/subscriptions       User
# 12  https://api.github.com/users/Dref360/subscript...       User
# 13  https://api.github.com/users/jfsantos/subscrip...       User
# 14  https://api.github.com/users/ahundt/subscriptions       User
# 15  https://api.github.com/users/myutwo150/subscri...       User
# 16  https://api.github.com/users/julienr/subscript...       User
# 17  https://api.github.com/users/gvtulder/subscrip...       User
# 18                                                NaN  Anonymous
# 19  https://api.github.com/users/tleeuwenburg/subs...       User
# 20  https://api.github.com/users/tboquet/subscript...       User
# 21  https://api.github.com/users/carlthome/subscri...       User
# 22  https://api.github.com/users/lukedeo/subscript...       User
# 23  https://api.github.com/users/olegsinyavskiy/su...       User
# 24  https://api.github.com/users/abhaikollara/subs...       User
# 25  https://api.github.com/users/yaringal/subscrip...       User
# 26  https://api.github.com/users/jihobak/subscript...       User
# 27  https://api.github.com/users/Danielhiversen/su...       User
# 28  https://api.github.com/users/jeammimi/subscrip...       User
# 29  https://api.github.com/users/gabrieldemarmiess...       User
#
#                                                 url
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# 11                                              NaN
# 12                                              NaN
# 13                                              NaN
# 14                                              NaN
# 15                                              NaN
# 16                                              NaN
# 17                                              NaN
# 18                                              NaN
# 19                                              NaN
# 20                                              NaN
# 21                                              NaN
# 22                                              NaN
# 23                                              NaN
# 24                                              NaN
# 25                                              NaN
# 26                                              NaN
# 27                                              NaN
# 28                                              NaN
# 29                                              NaN
# 0             https://api.github.com/users/fchollet
# 1        https://api.github.com/users/farizrahman4u
# 2             https://api.github.com/users/ozabluda
# 3           https://api.github.com/users/taehoonlee
# 4          https://api.github.com/users/EderSantana
# 5          https://api.github.com/users/maxpumperla
# 6              https://api.github.com/users/phreeza
# 7                  https://api.github.com/users/wxs
# 8          https://api.github.com/users/the-moliver
# 9              https://api.github.com/users/nzw0301
# 10          https://api.github.com/users/matsuyamax
# 11                https://api.github.com/users/tdhd
# 12             https://api.github.com/users/Dref360
# 13            https://api.github.com/users/jfsantos
# 14              https://api.github.com/users/ahundt
# 15           https://api.github.com/users/myutwo150
# 16             https://api.github.com/users/julienr
# 17            https://api.github.com/users/gvtulder
# 18                                              NaN
# 19        https://api.github.com/users/tleeuwenburg
# 20             https://api.github.com/users/tboquet
# 21           https://api.github.com/users/carlthome
# 22             https://api.github.com/users/lukedeo
# 23      https://api.github.com/users/olegsinyavskiy
# 24        https://api.github.com/users/abhaikollara
# 25            https://api.github.com/users/yaringal
# 26             https://api.github.com/users/jihobak
# 27      https://api.github.com/users/Danielhiversen
# 28            https://api.github.com/users/jeammimi
# 29  https://api.github.com/users/gabrieldemarmiesse

# %%
# Getting contributors

def get_contributors_github(orgname, repo):
    final = pd.DataFrame()
    for num in range(1,101):
        res = requests.get('https://api.github.com/repos/'+orgname+'/'+repo+'/contributors?anon=1&page='+str(num)).content
        if (len(pd.read_json(res)) > 0):
            dummy_df = pd.read_json(res)
            if (len(final)==0):
                final = dummy_df
            else:
                final = final.append(dummy_df)    
        else:
            print('done ok :)!!')
            break
    return final

# %%
data = get_content_github(orgname='tensorflow', repo = 'tensorflow')
# Out:
# done ok :)!!

# %%
len(data)
# Out:
# 1617

# %%
data= data.reset_index(drop=True)

# %%
data.to_json('tensorflow.json')
